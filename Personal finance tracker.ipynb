# %%
income= int(input("Enter income: "))
expense= int(input("Enter expense: "))
savings= income-expense
print("savings=", savings)
if savings>0:
    print("Good saving habit")
else:
    print("Need expense control")
# Out:
# Enter income:  50000
# Enter expense:  37000
# savings= 13000
# Good saving habit
